# %% [markdown]
# # here we have imported necessory the packages and modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import classification_report

# %% [markdown]
# # below We are reading from our csv raw data file.

# %%
url = 'http://bit.ly/w-data'

# %%
df = pd.read_csv(url)

# %%
df.info
# Out:
# <bound method DataFrame.info of     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86>

# %%
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %% [markdown]
# # Here we decide for supervised learning which label or column will be input for algoritham

# %%
X = pd.DataFrame(df.Hours)

# %%
X.head()
# Out:
#    Hours
# 0    2.5
# 1    5.1
# 2    3.2
# 3    8.5
# 4    3.5

# %% [markdown]
# # Here we decide for supervised learning which label or column will be output for algoritham

# %%
y = pd.DataFrame(df.Scores)

# %%
y.head()
# Out:
#    Scores
# 0      21
# 1      47
# 2      27
# 3      75
# 4      30

# %%
plt.scatter(X,y)
plt.show()

# %% [markdown]
# # here we want to devide our data frame or data set into Train data and Test data by using the model_selection module

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size= .85,random_state= 0)

# %%
len(X_train)
# Out:
# 21

# %% [markdown]
# # For creating model, we have created object of Linear Regression

# %%
model = LinearRegression()

# %% [markdown]
# # to train the model

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # checking the accuracy on training data

# %%
model.score(X_train, y_train)*100
# Out:
# 95.16157390656382

# %% [markdown]
# # prediction of test data

# %%
predicted_y = model.predict(X_test)

# %%
predicted_y
# Out:
# array([[16.92714815],
#        [33.7882695 ],
#        [75.44515755],
#        [26.84545482]])

# %% [markdown]
# # for Visualization of our model and prediction based on our data as follows

# %%
plt.scatter(X,y,color = 'green',marker= '*')
x_label = 'Hours'
plt.plot(X_test,predicted_y,color = 'purple')
plt.show()

# %% [markdown]
# # here in linear model we actualy calculate the slope and the intercept of the prediction line which is calculated while fitting the model and their values are as follows

# %%
coef = model.coef_
coef
# Out:
# array([[9.91830668]])

# %%
intercept = model.intercept_
intercept
# Out:
# array([2.04968813])

# %% [markdown]
# # here we are taking random input and our model is predicting the output according to its previous learning

# %%
s_x = float(input('enter no of hours student studied'))
# Out:
# enter no of hours student studied9.25

# %%
sample_x = np.array(s_x)

# %%
s1 = sample_x.reshape(1,-1)

# %%
print(model.predict(s1))
# Out:
# [[93.7940249]]

# %% [markdown]
# # we are checking the maen absolute error for our model

# %%
from sklearn import metrics

# %%
mean_value_error = metrics.mean_absolute_error(y_test,predicted_y)

# %%
mean_value_error
# Out:
# 4.865206019265337
